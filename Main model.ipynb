# %% [markdown]
# <div align="center">
#
# # VIDEO QA POLITIC FACT-CHECK BOT
#
# </div>

# %% [markdown]
# ##### My pipeline
# 1. Extract transcript from YouTube videos
# 2. Organize and clean the dataset
# 3. Build the RAG pipeline
# 4. Connect integrations (models, vector DB)
# 5. Generate embeddings
# 6. Optional local embedding models
# 7. Tokenization and chunking
# 8. Store embeddings in a vector database
# 9. Manage API keys securely
# 10. Build the chatbot interface

# %% [markdown]
# ## 1 Setup Environment (libraries & imports)

# %% [markdown]
# #### Install required libraries:

# %%
# =========================================================
# 1️⃣ YouTube transcript extraction
# Download transcripts from YouTube videos
# =========================================================
# !pip install youtube-transcript-api


# =========================================================
# 2️⃣ Data manipulation
# Organize transcripts, clean text, export datasets
# =========================================================
# !pip install pandas




# =========================================================
# 4️⃣ LangChain integrations
# External integrations (vector DBs, tools, etc.)
# =========================================================
# !pip install langchain-community


# =========================================================
# 5️⃣ LangChain text splitting (NEW PACKAGE)
# Required for RecursiveCharacterTextSplitter
# =========================================================
# !pip install langchain-text-splitters


# =========================================================
# 6️⃣ OpenAI integration
# Used for embeddings and chat models
# =========================================================
# !pip install langchain-openai openai


# =========================================================
# 7️⃣ Vector database
# Store embeddings and enable semantic search
# =========================================================
# !pip install chromadb


# =========================================================
# 8️⃣ Embedding models (optional local embeddings)
# Alternative to OpenAI embeddings
# =========================================================
# !pip install sentence-transformers


# =========================================================
# 9️⃣ Tokenization utilities
# Used for token counting and chunking
# =========================================================
# !pip install tiktoken


# =========================================================
# 🔟 Environment variables
# Manage API keys securely
# =========================================================
# !pip install python-dotenv


# =========================================================
# 1️⃣1️⃣ Chatbot web interface
# Optional interface for the final chatbot
# =========================================================
# !pip install streamlit

# Installing LangSmith for Second evaluation

# !pip install langsmith
# Out:
# Requirement already satisfied: youtube-transcript-api in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (1.2.4)
# Requirement already satisfied: defusedxml<0.8.0,>=0.7.1 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from youtube-transcript-api) (0.7.1)
# Requirement already satisfied: requests in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from youtube-transcript-api) (2.32.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from requests->youtube-transcript-api) (3.4.5)
# Requirement already satisfied: idna<4,>=2.5 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from requests->youtube-transcript-api) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from requests->youtube-transcript-api) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from requests->youtube-transcript-api) (2026.2.25)
# Requirement already satisfied: pandas in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (3.0.1)
# Requirement already satisfied: numpy>=1.26.0 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from pandas) (2025.3)
# Requirement already satisfied: six>=1.5 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: langchain-community in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (0.2.16)
# Requirement already satisfied: PyYAML>=5.3 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from langchain-community) (6.0.3)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from langchain-community) (2.0.48)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from langchain-community) (3.13.3)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: langchain<0.3.0,>=0.2.16 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from langchain-community) (0.2.16)
# Requirement already satisfied: langchain-core<0.3.0,>=0.2.38 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from langchain-community) (0.2.38)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.0 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from langchain-community) (0.1.147)
# Requirement already satisfied: numpy<2,>=1 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from langchain-community) (1.26.4)
# Requirement already satisfied: requests<3,>=2 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from langchain-community) (2.32.5)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.1.0 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from langchain-community) (8.5.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.23.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (3.26.2)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (0.9.0)
# Requirement already satisfied: langchain-text-splitters<0.3.0,>=0.2.0 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from langchain<0.3.0,>=0.2.16->langchain-community) (0.2.2)
# Requirement already satisfied: pydantic<3,>=1 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from langchain<0.3.0,>=0.2.16->langchain-community) (2.12.5)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from langchain-core<0.3.0,>=0.2.38->langchain-community) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from langchain-core<0.3.0,>=0.2.38->langchain-community) (24.2)
# Requirement already satisfied: typing-extensions>=4.7 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from langchain-core<0.3.0,>=0.2.38->langchain-community) (4.15.0)
# Requirement already satisfied: jsonpointer>=1.9 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.3.0,>=0.2.38->langchain-community) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from langsmith<0.2.0,>=0.1.0->langchain-community) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from langsmith<0.2.0,>=0.1.0->langchain-community) (3.11.7)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from langsmith<0.2.0,>=0.1.0->langchain-community) (1.0.0)
# Requirement already satisfied: anyio in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.0->langchain-community) (4.12.1)
# Requirement already satisfied: certifi in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.0->langchain-community) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.0->langchain-community) (1.0.9)
# Requirement already satisfied: idna in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.0->langchain-community) (3.11)
# Requirement already satisfied: h11>=0.16 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.0->langchain-community) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from pydantic<3,>=1->langchain<0.3.0,>=0.2.16->langchain-community) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from pydantic<3,>=1->langchain<0.3.0,>=0.2.16->langchain-community) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from pydantic<3,>=1->langchain<0.3.0,>=0.2.16->langchain-community) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from requests<3,>=2->langchain-community) (3.4.5)
# Requirement already satisfied: urllib3<3,>=1.21.1 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from requests<3,>=2->langchain-community) (2.6.3)
# Requirement already satisfied: greenlet>=1 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from SQLAlchemy<3,>=1.4->langchain-community) (3.3.2)
# Requirement already satisfied: mypy-extensions>=0.3.0 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community) (1.1.0)
# Requirement already satisfied: langchain-text-splitters in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (0.2.2)
# Requirement already satisfied: langchain-core<0.3.0,>=0.2.10 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from langchain-text-splitters) (0.2.38)
# Requirement already satisfied: PyYAML>=5.3 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from langchain-core<0.3.0,>=0.2.10->langchain-text-splitters) (6.0.3)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from langchain-core<0.3.0,>=0.2.10->langchain-text-splitters) (1.33)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.75 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from langchain-core<0.3.0,>=0.2.10->langchain-text-splitters) (0.1.147)
# Requirement already satisfied: packaging<25,>=23.2 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from langchain-core<0.3.0,>=0.2.10->langchain-text-splitters) (24.2)
# Requirement already satisfied: pydantic<3,>=1 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from langchain-core<0.3.0,>=0.2.10->langchain-text-splitters) (2.12.5)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.1.0 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from langchain-core<0.3.0,>=0.2.10->langchain-text-splitters) (8.5.0)
# Requirement already satisfied: typing-extensions>=4.7 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from langchain-core<0.3.0,>=0.2.10->langchain-text-splitters) (4.15.0)
# Requirement already satisfied: jsonpointer>=1.9 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.3.0,>=0.2.10->langchain-text-splitters) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from langsmith<0.2.0,>=0.1.75->langchain-core<0.3.0,>=0.2.10->langchain-text-splitters) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from langsmith<0.2.0,>=0.1.75->langchain-core<0.3.0,>=0.2.10->langchain-text-splitters) (3.11.7)
# Requirement already satisfied: requests<3,>=2 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from langsmith<0.2.0,>=0.1.75->langchain-core<0.3.0,>=0.2.10->langchain-text-splitters) (2.32.5)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from langsmith<0.2.0,>=0.1.75->langchain-core<0.3.0,>=0.2.10->langchain-text-splitters) (1.0.0)
# Requirement already satisfied: anyio in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.75->langchain-core<0.3.0,>=0.2.10->langchain-text-splitters) (4.12.1)
# Requirement already satisfied: certifi in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.75->langchain-core<0.3.0,>=0.2.10->langchain-text-splitters) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.75->langchain-core<0.3.0,>=0.2.10->langchain-text-splitters) (1.0.9)
# Requirement already satisfied: idna in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.75->langchain-core<0.3.0,>=0.2.10->langchain-text-splitters) (3.11)
# Requirement already satisfied: h11>=0.16 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.75->langchain-core<0.3.0,>=0.2.10->langchain-text-splitters) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from pydantic<3,>=1->langchain-core<0.3.0,>=0.2.10->langchain-text-splitters) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from pydantic<3,>=1->langchain-core<0.3.0,>=0.2.10->langchain-text-splitters) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from pydantic<3,>=1->langchain-core<0.3.0,>=0.2.10->langchain-text-splitters) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from requests<3,>=2->langsmith<0.2.0,>=0.1.75->langchain-core<0.3.0,>=0.2.10->langchain-text-splitters) (3.4.5)
# Requirement already satisfied: urllib3<3,>=1.21.1 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from requests<3,>=2->langsmith<0.2.0,>=0.1.75->langchain-core<0.3.0,>=0.2.10->langchain-text-splitters) (2.6.3)
# Requirement already satisfied: langchain-openai in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (0.1.23)
# Requirement already satisfied: openai in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (1.109.1)
# Requirement already satisfied: langchain-core<0.3.0,>=0.2.35 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from langchain-openai) (0.2.38)
# Requirement already satisfied: tiktoken<1,>=0.7 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from langchain-openai) (0.12.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from openai) (4.12.1)
# Requirement already satisfied: distro<2,>=1.7.0 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from openai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from openai) (0.13.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from openai) (2.12.5)
# Requirement already satisfied: sniffio in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from openai) (4.67.3)
# Requirement already satisfied: typing-extensions<5,>=4.11 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from openai) (4.15.0)
# Requirement already satisfied: idna>=2.8 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from anyio<5,>=3.5.0->openai) (3.11)
# Requirement already satisfied: certifi in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from httpx<1,>=0.23.0->openai) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from httpx<1,>=0.23.0->openai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.16.0)
# Requirement already satisfied: PyYAML>=5.3 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from langchain-core<0.3.0,>=0.2.35->langchain-openai) (6.0.3)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from langchain-core<0.3.0,>=0.2.35->langchain-openai) (1.33)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.75 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from langchain-core<0.3.0,>=0.2.35->langchain-openai) (0.1.147)
# Requirement already satisfied: packaging<25,>=23.2 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from langchain-core<0.3.0,>=0.2.35->langchain-openai) (24.2)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.1.0 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from langchain-core<0.3.0,>=0.2.35->langchain-openai) (8.5.0)
# Requirement already satisfied: jsonpointer>=1.9 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.3.0,>=0.2.35->langchain-openai) (3.0.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from langsmith<0.2.0,>=0.1.75->langchain-core<0.3.0,>=0.2.35->langchain-openai) (3.11.7)
# Requirement already satisfied: requests<3,>=2 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from langsmith<0.2.0,>=0.1.75->langchain-core<0.3.0,>=0.2.35->langchain-openai) (2.32.5)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from langsmith<0.2.0,>=0.1.75->langchain-core<0.3.0,>=0.2.35->langchain-openai) (1.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from pydantic<3,>=1.9.0->openai) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from pydantic<3,>=1.9.0->openai) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from requests<3,>=2->langsmith<0.2.0,>=0.1.75->langchain-core<0.3.0,>=0.2.35->langchain-openai) (3.4.5)
# Requirement already satisfied: urllib3<3,>=1.21.1 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from requests<3,>=2->langsmith<0.2.0,>=0.1.75->langchain-core<0.3.0,>=0.2.35->langchain-openai) (2.6.3)
# Requirement already satisfied: regex>=2022.1.18 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from tiktoken<1,>=0.7->langchain-openai) (2026.2.28)
# Requirement already satisfied: colorama in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from tqdm>4->openai) (0.4.6)
# Requirement already satisfied: chromadb in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (1.5.5)
# Requirement already satisfied: build>=1.0.3 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from chromadb) (1.4.0)
# Requirement already satisfied: pydantic>=2.0 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from chromadb) (2.12.5)
# Requirement already satisfied: pydantic-settings>=2.0 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from chromadb) (2.13.1)
# Requirement already satisfied: pybase64>=1.4.1 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from chromadb) (1.4.3)
# Requirement already satisfied: uvicorn>=0.18.3 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.41.0)
# Requirement already satisfied: numpy>=1.22.5 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from chromadb) (1.26.4)
# Requirement already satisfied: typing-extensions>=4.5.0 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from chromadb) (4.15.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from chromadb) (1.24.3)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from chromadb) (1.40.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from chromadb) (1.40.0)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from chromadb) (1.40.0)
# Requirement already satisfied: tokenizers>=0.13.2 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from chromadb) (0.22.2)
# Requirement already satisfied: pypika>=0.48.9 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from chromadb) (0.51.1)
# Requirement already satisfied: tqdm>=4.65.0 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from chromadb) (4.67.3)
# Requirement already satisfied: overrides>=7.3.1 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from chromadb) (7.7.0)
# Requirement already satisfied: importlib-resources in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from chromadb) (6.5.2)
# Requirement already satisfied: grpcio>=1.58.0 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from chromadb) (1.78.0)
# Requirement already satisfied: bcrypt>=4.0.1 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from chromadb) (5.0.0)
# Requirement already satisfied: typer>=0.9.0 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from chromadb) (0.24.1)
# Requirement already satisfied: kubernetes>=28.1.0 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from chromadb) (35.0.0)
# Requirement already satisfied: tenacity>=8.2.3 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from chromadb) (8.5.0)
# Requirement already satisfied: pyyaml>=6.0.0 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from chromadb) (6.0.3)
# Requirement already satisfied: mmh3>=4.0.1 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from chromadb) (5.2.1)
# Requirement already satisfied: orjson>=3.9.12 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from chromadb) (3.11.7)
# Requirement already satisfied: httpx>=0.27.0 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from chromadb) (0.28.1)
# Requirement already satisfied: rich>=10.11.0 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from chromadb) (14.3.3)
# Requirement already satisfied: jsonschema>=4.19.0 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from chromadb) (4.26.0)
# Requirement already satisfied: packaging>=24.0 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from build>=1.0.3->chromadb) (24.2)
# Requirement already satisfied: pyproject_hooks in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from build>=1.0.3->chromadb) (1.2.0)
# Requirement already satisfied: colorama in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from build>=1.0.3->chromadb) (0.4.6)
# Requirement already satisfied: anyio in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from httpx>=0.27.0->chromadb) (4.12.1)
# Requirement already satisfied: certifi in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from httpx>=0.27.0->chromadb) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from httpx>=0.27.0->chromadb) (1.0.9)
# Requirement already satisfied: idna in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from httpx>=0.27.0->chromadb) (3.11)
# Requirement already satisfied: h11>=0.16 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb) (0.16.0)
# Requirement already satisfied: attrs>=22.2.0 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from jsonschema>=4.19.0->chromadb) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from jsonschema>=4.19.0->chromadb) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from jsonschema>=4.19.0->chromadb) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from jsonschema>=4.19.0->chromadb) (0.30.0)
# Requirement already satisfied: six>=1.9.0 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.9.0.post0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.9.0)
# Requirement already satisfied: requests in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.32.5)
# Requirement already satisfied: requests-oauthlib in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.0.0)
# Requirement already satisfied: urllib3!=2.6.0,>=1.24.2 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.6.3)
# Requirement already satisfied: durationpy>=0.7 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from kubernetes>=28.1.0->chromadb) (0.10)
# Requirement already satisfied: flatbuffers in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from onnxruntime>=1.14.1->chromadb) (25.12.19)
# Requirement already satisfied: protobuf in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from onnxruntime>=1.14.1->chromadb) (6.33.5)
# Requirement already satisfied: sympy in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from onnxruntime>=1.14.1->chromadb) (1.14.0)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from opentelemetry-api>=1.2.0->chromadb) (8.7.1)
# Requirement already satisfied: zipp>=3.20 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.2.0->chromadb) (3.23.0)
# Requirement already satisfied: googleapis-common-protos~=1.57 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.72.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.40.0 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.40.0)
# Requirement already satisfied: opentelemetry-proto==1.40.0 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.40.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.61b0 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from opentelemetry-sdk>=1.2.0->chromadb) (0.61b0)
# Requirement already satisfied: annotated-types>=0.6.0 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from pydantic>=2.0->chromadb) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from pydantic>=2.0->chromadb) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from pydantic>=2.0->chromadb) (0.4.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from pydantic-settings>=2.0->chromadb) (1.2.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from rich>=10.11.0->chromadb) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from rich>=10.11.0->chromadb) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb) (0.1.2)
# Requirement already satisfied: huggingface-hub<2.0,>=0.16.4 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from tokenizers>=0.13.2->chromadb) (1.6.0)
# Requirement already satisfied: filelock>=3.10.0 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (3.25.0)
# Requirement already satisfied: fsspec>=2023.5.0 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (2026.2.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.3.2 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (1.3.2)
# Requirement already satisfied: click>=8.2.1 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from typer>=0.9.0->chromadb) (8.3.1)
# Requirement already satisfied: shellingham>=1.3.0 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from typer>=0.9.0->chromadb) (1.5.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from typer>=0.9.0->chromadb) (0.0.4)
# Requirement already satisfied: httptools>=0.6.3 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.7.1)
# Requirement already satisfied: watchfiles>=0.20 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.1.1)
# Requirement already satisfied: websockets>=10.4 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (16.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from requests->kubernetes>=28.1.0->chromadb) (3.4.5)
# Requirement already satisfied: oauthlib>=3.0.0 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from requests-oauthlib->kubernetes>=28.1.0->chromadb) (3.3.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.3.0)
# Requirement already satisfied: sentence-transformers in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (5.2.3)
# Requirement already satisfied: transformers<6.0.0,>=4.41.0 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from sentence-transformers) (5.3.0)
# Requirement already satisfied: huggingface-hub>=0.20.0 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from sentence-transformers) (1.6.0)
# Requirement already satisfied: torch>=1.11.0 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from sentence-transformers) (2.10.0)
# Requirement already satisfied: numpy in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from sentence-transformers) (1.26.4)
# Requirement already satisfied: scikit-learn in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from sentence-transformers) (1.8.0)
# Requirement already satisfied: scipy in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from sentence-transformers) (1.17.1)
# Requirement already satisfied: typing_extensions>=4.5.0 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from sentence-transformers) (4.15.0)
# Requirement already satisfied: tqdm in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from sentence-transformers) (4.67.3)
# Requirement already satisfied: packaging>=20.0 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (2026.2.28)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (0.22.2)
# Requirement already satisfied: typer in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (0.24.1)
# Requirement already satisfied: safetensors>=0.4.3 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (0.7.0)
# Requirement already satisfied: filelock>=3.10.0 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (3.25.0)
# Requirement already satisfied: fsspec>=2023.5.0 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2026.2.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.3.2 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (1.3.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (0.28.1)
# Requirement already satisfied: anyio in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.20.0->sentence-transformers) (4.12.1)
# Requirement already satisfied: certifi in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.20.0->sentence-transformers) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.20.0->sentence-transformers) (1.0.9)
# Requirement already satisfied: idna in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.20.0->sentence-transformers) (3.11)
# Requirement already satisfied: h11>=0.16 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub>=0.20.0->sentence-transformers) (0.16.0)
# Requirement already satisfied: sympy>=1.13.3 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from torch>=1.11.0->sentence-transformers) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.6.1)
# Requirement already satisfied: jinja2 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.1.6)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from sympy>=1.13.3->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: colorama in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from tqdm->sentence-transformers) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (3.0.3)
# Requirement already satisfied: joblib>=1.3.0 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from scikit-learn->sentence-transformers) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from scikit-learn->sentence-transformers) (3.6.0)
# Requirement already satisfied: click>=8.2.1 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from typer->transformers<6.0.0,>=4.41.0->sentence-transformers) (8.3.1)
# Requirement already satisfied: shellingham>=1.3.0 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from typer->transformers<6.0.0,>=4.41.0->sentence-transformers) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from typer->transformers<6.0.0,>=4.41.0->sentence-transformers) (14.3.3)
# Requirement already satisfied: annotated-doc>=0.0.2 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from typer->transformers<6.0.0,>=4.41.0->sentence-transformers) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from rich>=12.3.0->typer->transformers<6.0.0,>=4.41.0->sentence-transformers) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from rich>=12.3.0->typer->transformers<6.0.0,>=4.41.0->sentence-transformers) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer->transformers<6.0.0,>=4.41.0->sentence-transformers) (0.1.2)
# Requirement already satisfied: tiktoken in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (0.12.0)
# Requirement already satisfied: regex>=2022.1.18 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from tiktoken) (2026.2.28)
# Requirement already satisfied: requests>=2.26.0 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from tiktoken) (2.32.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from requests>=2.26.0->tiktoken) (3.4.5)
# Requirement already satisfied: idna<4,>=2.5 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from requests>=2.26.0->tiktoken) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from requests>=2.26.0->tiktoken) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from requests>=2.26.0->tiktoken) (2026.2.25)
# Requirement already satisfied: python-dotenv in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (1.2.2)
# Requirement already satisfied: streamlit in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (1.55.0)
# Requirement already satisfied: altair!=5.4.0,!=5.4.1,<7,>=4.0 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from streamlit) (6.0.0)
# Requirement already satisfied: blinker<2,>=1.5.0 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from streamlit) (1.9.0)
# Requirement already satisfied: cachetools<8,>=5.5 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from streamlit) (7.0.3)
# Requirement already satisfied: click<9,>=7.0 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from streamlit) (8.3.1)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from streamlit) (3.1.46)
# Requirement already satisfied: numpy<3,>=1.23 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from streamlit) (1.26.4)
# Requirement already satisfied: packaging>=20 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from streamlit) (24.2)
# Collecting pandas<3,>=1.4.0 (from streamlit)
#   Using cached pandas-2.3.3-cp311-cp311-win_amd64.whl.metadata (19 kB)
# Requirement already satisfied: pillow<13,>=7.1.0 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from streamlit) (12.1.1)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from streamlit) (0.9.1)
# Requirement already satisfied: protobuf<7,>=3.20 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from streamlit) (6.33.5)
# Requirement already satisfied: pyarrow>=7.0 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from streamlit) (23.0.1)
# Requirement already satisfied: requests<3,>=2.27 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from streamlit) (2.32.5)
# Requirement already satisfied: tenacity<10,>=8.1.0 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from streamlit) (8.5.0)
# Requirement already satisfied: toml<2,>=0.10.1 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: tornado!=6.5.0,<7,>=6.0.3 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from streamlit) (6.5.4)
# Requirement already satisfied: typing-extensions<5,>=4.10.0 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from streamlit) (4.15.0)
# Requirement already satisfied: watchdog<7,>=2.1.5 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from streamlit) (6.0.0)
# Requirement already satisfied: jinja2 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (3.1.6)
# Requirement already satisfied: jsonschema>=3.0 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (4.26.0)
# Requirement already satisfied: narwhals>=1.27.1 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (2.17.0)
# Requirement already satisfied: colorama in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from click<9,>=7.0->streamlit) (0.4.6)
# Requirement already satisfied: gitdb<5,>=4.0.1 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (5.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2026.1.post1)
# Requirement already satisfied: tzdata>=2022.7 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2025.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from requests<3,>=2.27->streamlit) (3.4.5)
# Requirement already satisfied: idna<4,>=2.5 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from requests<3,>=2.27->streamlit) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from requests<3,>=2.27->streamlit) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from requests<3,>=2.27->streamlit) (2026.2.25)
# Requirement already satisfied: MarkupSafe>=2.0 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from jinja2->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (3.0.3)
# Requirement already satisfied: attrs>=22.2.0 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (0.30.0)
# Requirement already satisfied: six>=1.5 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from python-dateutil>=2.8.2->pandas<3,>=1.4.0->streamlit) (1.17.0)
# Using cached pandas-2.3.3-cp311-cp311-win_amd64.whl (11.3 MB)
# Installing collected packages: pandas
#   Attempting uninstall: pandas
#     Found existing installation: pandas 3.0.1
#     Uninstalling pandas-3.0.1:
#       Successfully uninstalled pandas-3.0.1
# Successfully installed pandas-2.3.3
# Requirement already satisfied: langsmith in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (0.1.147)
# Requirement already satisfied: httpx<1,>=0.23.0 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from langsmith) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from langsmith) (3.11.7)
# Requirement already satisfied: pydantic<3,>=1 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from langsmith) (2.12.5)
# Requirement already satisfied: requests<3,>=2 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from langsmith) (2.32.5)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from langsmith) (1.0.0)
# Requirement already satisfied: anyio in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from httpx<1,>=0.23.0->langsmith) (4.12.1)
# Requirement already satisfied: certifi in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from httpx<1,>=0.23.0->langsmith) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from httpx<1,>=0.23.0->langsmith) (1.0.9)
# Requirement already satisfied: idna in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from httpx<1,>=0.23.0->langsmith) (3.11)
# Requirement already satisfied: h11>=0.16 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from pydantic<3,>=1->langsmith) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from pydantic<3,>=1->langsmith) (2.41.5)
# Requirement already satisfied: typing-extensions>=4.14.1 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from pydantic<3,>=1->langsmith) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from pydantic<3,>=1->langsmith) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from requests<3,>=2->langsmith) (3.4.5)
# Requirement already satisfied: urllib3<3,>=1.21.1 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from requests<3,>=2->langsmith) (2.6.3)

# %%
# !pip uninstall -y langchain langchain-core langchain-community langchain-openai langchain-text-splitters
# Out:
# Found existing installation: langchain 0.2.16
# Uninstalling langchain-0.2.16:
#   Successfully uninstalled langchain-0.2.16
# Found existing installation: langchain-core 0.2.38
# Uninstalling langchain-core-0.2.38:
#   Successfully uninstalled langchain-core-0.2.38
# Found existing installation: langchain-community 0.2.16
# Uninstalling langchain-community-0.2.16:
#   Successfully uninstalled langchain-community-0.2.16
# Found existing installation: langchain-openai 0.1.23
# Uninstalling langchain-openai-0.1.23:
#   Successfully uninstalled langchain-openai-0.1.23
# Found existing installation: langchain-text-splitters 0.2.2
# Uninstalling langchain-text-splitters-0.2.2:
#   Successfully uninstalled langchain-text-splitters-0.2.2

# %%
# !pip install langchain==0.2.16 \
langchain-core==0.2.38 \
langchain-community==0.2.16 \
langchain-openai==0.1.23 \
langchain-text-splitters==0.2.2
# Out:
# Collecting langchain==0.2.16
#   Using cached langchain-0.2.16-py3-none-any.whl.metadata (7.1 kB)
# Collecting langchain-core==0.2.38
#   Using cached langchain_core-0.2.38-py3-none-any.whl.metadata (6.2 kB)
# Collecting langchain-community==0.2.16
#   Using cached langchain_community-0.2.16-py3-none-any.whl.metadata (2.7 kB)
# Collecting langchain-openai==0.1.23
#   Using cached langchain_openai-0.1.23-py3-none-any.whl.metadata (2.6 kB)
# Collecting langchain-text-splitters==0.2.2
#   Using cached langchain_text_splitters-0.2.2-py3-none-any.whl.metadata (2.1 kB)
# Requirement already satisfied: PyYAML>=5.3 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from langchain==0.2.16) (6.0.3)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from langchain==0.2.16) (2.0.48)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from langchain==0.2.16) (3.13.3)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.17 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from langchain==0.2.16) (0.1.147)
# Requirement already satisfied: numpy<2,>=1 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from langchain==0.2.16) (1.26.4)
# Requirement already satisfied: pydantic<3,>=1 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from langchain==0.2.16) (2.12.5)
# Requirement already satisfied: requests<3,>=2 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from langchain==0.2.16) (2.32.5)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.1.0 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from langchain==0.2.16) (8.5.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from langchain-core==0.2.38) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from langchain-core==0.2.38) (24.2)
# Requirement already satisfied: typing-extensions>=4.7 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from langchain-core==0.2.38) (4.15.0)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from langchain-community==0.2.16) (0.6.7)
# Requirement already satisfied: openai<2.0.0,>=1.40.0 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from langchain-openai==0.1.23) (1.109.1)
# Requirement already satisfied: tiktoken<1,>=0.7 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from langchain-openai==0.1.23) (0.12.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.2.16) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.2.16) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.2.16) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.2.16) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.2.16) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.2.16) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.2.16) (1.23.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community==0.2.16) (3.26.2)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community==0.2.16) (0.9.0)
# Requirement already satisfied: jsonpointer>=1.9 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core==0.2.38) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from langsmith<0.2.0,>=0.1.17->langchain==0.2.16) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from langsmith<0.2.0,>=0.1.17->langchain==0.2.16) (3.11.7)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from langsmith<0.2.0,>=0.1.17->langchain==0.2.16) (1.0.0)
# Requirement already satisfied: anyio in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain==0.2.16) (4.12.1)
# Requirement already satisfied: certifi in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain==0.2.16) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain==0.2.16) (1.0.9)
# Requirement already satisfied: idna in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain==0.2.16) (3.11)
# Requirement already satisfied: h11>=0.16 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain==0.2.16) (0.16.0)
# Requirement already satisfied: distro<2,>=1.7.0 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from openai<2.0.0,>=1.40.0->langchain-openai==0.1.23) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from openai<2.0.0,>=1.40.0->langchain-openai==0.1.23) (0.13.0)
# Requirement already satisfied: sniffio in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from openai<2.0.0,>=1.40.0->langchain-openai==0.1.23) (1.3.1)
# Requirement already satisfied: tqdm>4 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from openai<2.0.0,>=1.40.0->langchain-openai==0.1.23) (4.67.3)
# Requirement already satisfied: annotated-types>=0.6.0 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from pydantic<3,>=1->langchain==0.2.16) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from pydantic<3,>=1->langchain==0.2.16) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from pydantic<3,>=1->langchain==0.2.16) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from requests<3,>=2->langchain==0.2.16) (3.4.5)
# Requirement already satisfied: urllib3<3,>=1.21.1 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from requests<3,>=2->langchain==0.2.16) (2.6.3)
# Requirement already satisfied: greenlet>=1 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from SQLAlchemy<3,>=1.4->langchain==0.2.16) (3.3.2)
# Requirement already satisfied: regex>=2022.1.18 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from tiktoken<1,>=0.7->langchain-openai==0.1.23) (2026.2.28)
# Requirement already satisfied: mypy-extensions>=0.3.0 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community==0.2.16) (1.1.0)
# Requirement already satisfied: colorama in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from tqdm>4->openai<2.0.0,>=1.40.0->langchain-openai==0.1.23) (0.4.6)
# Using cached langchain-0.2.16-py3-none-any.whl (1.0 MB)
# Using cached langchain_core-0.2.38-py3-none-any.whl (396 kB)
# Using cached langchain_text_splitters-0.2.2-py3-none-any.whl (25 kB)
# Using cached langchain_community-0.2.16-py3-none-any.whl (2.3 MB)
# Using cached langchain_openai-0.1.23-py3-none-any.whl (51 kB)
# Installing collected packages: langchain-core, langchain-text-splitters, langchain-openai, langchain, langchain-community
#
#    ---------------------------------------- 0/5 [langchain-core]
#    ---------------------------------------- 0/5 [langchain-core]
#    ---------------------------------------- 0/5 [langchain-core]
#    ---------------------------------------- 0/5 [langchain-core]
#    ---------------------------------------- 0/5 [langchain-core]
#    -------- ------------------------------- 1/5 [langchain-text-splitters]
#    ------------------------ --------------- 3/5 [langchain]
#    ------------------------ --------------- 3/5 [langchain]
#    ------------------------ --------------- 3/5 [langchain]
#    ------------------------ --------------- 3/5 [langchain]
#    ------------------------ --------------- 3/5 [langchain]
#    ------------------------ --------------- 3/5 [langchain]
#    ------------------------ --------------- 3/5 [langchain]
#    ------------------------ --------------- 3/5 [langchain]
#    ------------------------ --------------- 3/5 [langchain]
#    ------------------------ --------------- 3/5 [langchain]
#    ------------------------ --------------- 3/5 [langchain]
#    ------------------------ --------------- 3/5 [langchain]
#    ------------------------ --------------- 3/5 [langchain]
#    ------------------------ --------------- 3/5 [langchain]
#    ------------------------ --------------- 3/5 [langchain]
#    ------------------------ --------------- 3/5 [langchain]
#    ------------------------ --------------- 3/5 [langchain]
#    ------------------------ --------------- 3/5 [langchain]
#    ------------------------ --------------- 3/5 [langchain]
#    ------------------------ --------------- 3/5 [langchain]
#    ------------------------ --------------- 3/5 [langchain]
#    ------------------------ --------------- 3/5 [langchain]
#    ------------------------ --------------- 3/5 [langchain]
#    ------------------------ --------------- 3/5 [langchain]
#    ------------------------ --------------- 3/5 [langchain]
#    ------------------------ --------------- 3/5 [langchain]
#    ------------------------ --------------- 3/5 [langchain]
#    ------------------------ --------------- 3/5 [langchain]
#    ------------------------ --------------- 3/5 [langchain]
#    ------------------------ --------------- 3/5 [langchain]
#    ------------------------ --------------- 3/5 [langchain]
#    ------------------------ --------------- 3/5 [langchain]
#    ------------------------ --------------- 3/5 [langchain]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    ---------------------------------------- 5/5 [langchain-community]
#
# Successfully installed langchain-0.2.16 langchain-community-0.2.16 langchain-core-0.2.38 langchain-openai-0.1.23 langchain-text-splitters-0.2.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# langchain-classic 1.0.2 requires langchain-core<2.0.0,>=1.2.17, but you have langchain-core 0.2.38 which is incompatible.
# langchain-classic 1.0.2 requires langchain-text-splitters<2.0.0,>=1.1.0, but you have langchain-text-splitters 0.2.2 which is incompatible.
# langgraph-prebuilt 1.0.8 requires langchain-core>=1.0.0, but you have langchain-core 0.2.38 which is incompatible.

# %%
# !pip install -U \
langchain==0.2.16 \
langchain-community==0.2.16 \
langchain-openai==0.1.23 \
langchain-text-splitters==0.2.2 \
chromadb \
youtube-transcript-api \
pandas \
openai \
tiktoken
# Out:
# Requirement already satisfied: langchain==0.2.16 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (0.2.16)
# Requirement already satisfied: langchain-community==0.2.16 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (0.2.16)
# Requirement already satisfied: langchain-openai==0.1.23 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (0.1.23)
# Requirement already satisfied: langchain-text-splitters==0.2.2 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (0.2.2)
# Requirement already satisfied: chromadb in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (1.5.5)
# Requirement already satisfied: youtube-transcript-api in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (1.2.4)
# Requirement already satisfied: pandas in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (2.3.3)
# Collecting pandas
#   Using cached pandas-3.0.1-cp311-cp311-win_amd64.whl.metadata (19 kB)
# Requirement already satisfied: openai in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (1.109.1)
# Collecting openai
#   Using cached openai-2.26.0-py3-none-any.whl.metadata (29 kB)
# Requirement already satisfied: tiktoken in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (0.12.0)
# Requirement already satisfied: PyYAML>=5.3 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from langchain==0.2.16) (6.0.3)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from langchain==0.2.16) (2.0.48)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from langchain==0.2.16) (3.13.3)
# Requirement already satisfied: langchain-core<0.3.0,>=0.2.38 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from langchain==0.2.16) (0.2.38)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.17 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from langchain==0.2.16) (0.1.147)
# Requirement already satisfied: numpy<2,>=1 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from langchain==0.2.16) (1.26.4)
# Requirement already satisfied: pydantic<3,>=1 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from langchain==0.2.16) (2.12.5)
# Requirement already satisfied: requests<3,>=2 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from langchain==0.2.16) (2.32.5)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.1.0 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from langchain==0.2.16) (8.5.0)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from langchain-community==0.2.16) (0.6.7)
# Requirement already satisfied: anyio<5,>=3.5.0 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from openai) (4.12.1)
# Requirement already satisfied: distro<2,>=1.7.0 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from openai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from openai) (0.13.0)
# Requirement already satisfied: sniffio in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from openai) (4.67.3)
# Requirement already satisfied: typing-extensions<5,>=4.11 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from openai) (4.15.0)
# Requirement already satisfied: regex>=2022.1.18 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from tiktoken) (2026.2.28)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.2.16) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.2.16) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.2.16) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.2.16) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.2.16) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.2.16) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.2.16) (1.23.0)
# Requirement already satisfied: idna>=2.8 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from anyio<5,>=3.5.0->openai) (3.11)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community==0.2.16) (3.26.2)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community==0.2.16) (0.9.0)
# Requirement already satisfied: certifi in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from httpx<1,>=0.23.0->openai) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from httpx<1,>=0.23.0->openai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.16.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from langchain-core<0.3.0,>=0.2.38->langchain==0.2.16) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from langchain-core<0.3.0,>=0.2.38->langchain==0.2.16) (24.2)
# Requirement already satisfied: jsonpointer>=1.9 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.3.0,>=0.2.38->langchain==0.2.16) (3.0.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from langsmith<0.2.0,>=0.1.17->langchain==0.2.16) (3.11.7)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from langsmith<0.2.0,>=0.1.17->langchain==0.2.16) (1.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from pydantic<3,>=1->langchain==0.2.16) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from pydantic<3,>=1->langchain==0.2.16) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from pydantic<3,>=1->langchain==0.2.16) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from requests<3,>=2->langchain==0.2.16) (3.4.5)
# Requirement already satisfied: urllib3<3,>=1.21.1 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from requests<3,>=2->langchain==0.2.16) (2.6.3)
# Requirement already satisfied: greenlet>=1 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from SQLAlchemy<3,>=1.4->langchain==0.2.16) (3.3.2)
# Requirement already satisfied: mypy-extensions>=0.3.0 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community==0.2.16) (1.1.0)
# Requirement already satisfied: build>=1.0.3 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from chromadb) (1.4.0)
# Requirement already satisfied: pydantic-settings>=2.0 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from chromadb) (2.13.1)
# Requirement already satisfied: pybase64>=1.4.1 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from chromadb) (1.4.3)
# Requirement already satisfied: uvicorn>=0.18.3 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.41.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from chromadb) (1.24.3)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from chromadb) (1.40.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from chromadb) (1.40.0)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from chromadb) (1.40.0)
# Requirement already satisfied: tokenizers>=0.13.2 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from chromadb) (0.22.2)
# Requirement already satisfied: pypika>=0.48.9 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from chromadb) (0.51.1)
# Requirement already satisfied: overrides>=7.3.1 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from chromadb) (7.7.0)
# Requirement already satisfied: importlib-resources in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from chromadb) (6.5.2)
# Requirement already satisfied: grpcio>=1.58.0 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from chromadb) (1.78.0)
# Requirement already satisfied: bcrypt>=4.0.1 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from chromadb) (5.0.0)
# Requirement already satisfied: typer>=0.9.0 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from chromadb) (0.24.1)
# Requirement already satisfied: kubernetes>=28.1.0 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from chromadb) (35.0.0)
# Requirement already satisfied: mmh3>=4.0.1 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from chromadb) (5.2.1)
# Requirement already satisfied: rich>=10.11.0 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from chromadb) (14.3.3)
# Requirement already satisfied: jsonschema>=4.19.0 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from chromadb) (4.26.0)
# Requirement already satisfied: defusedxml<0.8.0,>=0.7.1 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from youtube-transcript-api) (0.7.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from pandas) (2025.3)
# Requirement already satisfied: pyproject_hooks in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from build>=1.0.3->chromadb) (1.2.0)
# Requirement already satisfied: colorama in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from build>=1.0.3->chromadb) (0.4.6)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from jsonschema>=4.19.0->chromadb) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from jsonschema>=4.19.0->chromadb) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from jsonschema>=4.19.0->chromadb) (0.30.0)
# Requirement already satisfied: six>=1.9.0 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.17.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.9.0)
# Requirement already satisfied: requests-oauthlib in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.0.0)
# Requirement already satisfied: durationpy>=0.7 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from kubernetes>=28.1.0->chromadb) (0.10)
# Requirement already satisfied: flatbuffers in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from onnxruntime>=1.14.1->chromadb) (25.12.19)
# Requirement already satisfied: protobuf in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from onnxruntime>=1.14.1->chromadb) (6.33.5)
# Requirement already satisfied: sympy in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from onnxruntime>=1.14.1->chromadb) (1.14.0)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from opentelemetry-api>=1.2.0->chromadb) (8.7.1)
# Requirement already satisfied: zipp>=3.20 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.2.0->chromadb) (3.23.0)
# Requirement already satisfied: googleapis-common-protos~=1.57 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.72.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.40.0 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.40.0)
# Requirement already satisfied: opentelemetry-proto==1.40.0 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.40.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.61b0 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from opentelemetry-sdk>=1.2.0->chromadb) (0.61b0)
# Requirement already satisfied: python-dotenv>=0.21.0 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from pydantic-settings>=2.0->chromadb) (1.2.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from rich>=10.11.0->chromadb) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from rich>=10.11.0->chromadb) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb) (0.1.2)
# Requirement already satisfied: huggingface-hub<2.0,>=0.16.4 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from tokenizers>=0.13.2->chromadb) (1.6.0)
# Requirement already satisfied: filelock>=3.10.0 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (3.25.0)
# Requirement already satisfied: fsspec>=2023.5.0 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (2026.2.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.3.2 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (1.3.2)
# Requirement already satisfied: click>=8.2.1 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from typer>=0.9.0->chromadb) (8.3.1)
# Requirement already satisfied: shellingham>=1.3.0 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from typer>=0.9.0->chromadb) (1.5.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from typer>=0.9.0->chromadb) (0.0.4)
# Requirement already satisfied: httptools>=0.6.3 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.7.1)
# Requirement already satisfied: watchfiles>=0.20 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.1.1)
# Requirement already satisfied: websockets>=10.4 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (16.0)
# Requirement already satisfied: oauthlib>=3.0.0 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from requests-oauthlib->kubernetes>=28.1.0->chromadb) (3.3.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.3.0)
# Using cached pandas-3.0.1-cp311-cp311-win_amd64.whl (9.9 MB)
# Installing collected packages: pandas
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.3.3
#     Uninstalling pandas-2.3.3:
#       Successfully uninstalled pandas-2.3.3
# Successfully installed pandas-3.0.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# streamlit 1.55.0 requires pandas<3,>=1.4.0, but you have pandas 3.0.1 which is incompatible.

# %%
# Modification: add Spacey
# !pip install spacy
# !python -m spacy download en_core_web_sm
# Out:
# Requirement already satisfied: spacy in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (3.8.11)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from spacy) (1.0.15)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from spacy) (2.0.13)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from spacy) (3.0.12)
# Requirement already satisfied: thinc<8.4.0,>=8.3.4 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from spacy) (8.3.10)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from spacy) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from spacy) (2.5.2)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.4.2 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from spacy) (0.4.3)
# Requirement already satisfied: typer-slim<1.0.0,>=0.3.0 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from spacy) (0.24.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from spacy) (4.67.3)
# Requirement already satisfied: numpy>=1.19.0 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from spacy) (1.26.4)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from spacy) (2.32.5)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from spacy) (2.12.5)
# Requirement already satisfied: jinja2 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from spacy) (3.1.6)
# Requirement already satisfied: setuptools in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from spacy) (80.10.2)
# Requirement already satisfied: packaging>=20.0 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from spacy) (24.2)
# Requirement already satisfied: annotated-types>=0.6.0 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (2.41.5)
# Requirement already satisfied: typing-extensions>=4.14.1 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4.5)
# Requirement already satisfied: idna<4,>=2.5 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2026.2.25)
# Requirement already satisfied: blis<1.4.0,>=1.3.0 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from thinc<8.4.0,>=8.3.4->spacy) (1.3.3)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from thinc<8.4.0,>=8.3.4->spacy) (0.1.5)
# Requirement already satisfied: colorama in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy) (0.4.6)
# Requirement already satisfied: typer>=0.24.0 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from typer-slim<1.0.0,>=0.3.0->spacy) (0.24.1)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from weasel<0.5.0,>=0.4.2->spacy) (0.23.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from weasel<0.5.0,>=0.4.2->spacy) (7.5.1)
# Requirement already satisfied: wrapt in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.4.2->spacy) (2.1.2)
# Requirement already satisfied: click>=8.2.1 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from typer>=0.24.0->typer-slim<1.0.0,>=0.3.0->spacy) (8.3.1)
# Requirement already satisfied: shellingham>=1.3.0 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from typer>=0.24.0->typer-slim<1.0.0,>=0.3.0->spacy) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from typer>=0.24.0->typer-slim<1.0.0,>=0.3.0->spacy) (14.3.3)
# Requirement already satisfied: annotated-doc>=0.0.2 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from typer>=0.24.0->typer-slim<1.0.0,>=0.3.0->spacy) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from rich>=12.3.0->typer>=0.24.0->typer-slim<1.0.0,>=0.3.0->spacy) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from rich>=12.3.0->typer>=0.24.0->typer-slim<1.0.0,>=0.3.0->spacy) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer>=0.24.0->typer-slim<1.0.0,>=0.3.0->spacy) (0.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in C:\Users\quinc\anaconda3\envs\langchain311\Lib\site-packages (from jinja2->spacy) (3.0.3)
# Collecting en-core-web-sm==3.8.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.8.0/en_core_web_sm-3.8.0-py3-none-any.whl
#      - 0 bytes ? 0:00:00
#      - 0 bytes ? 0:00:00
# ERROR: Wheel 'en-core-web-sm' located at C:\Users\quinc\AppData\Local\Temp\pip-unpack-emtrnhc2\en_core_web_sm-3.8.0-py3-none-any.whl is invalid.

# %% [markdown]
# #### Import Libraries

# %%
# Data handling
import pandas as pd

# YouTube transcript extraction
from youtube_transcript_api import YouTubeTranscriptApi

# NLP preprocessing (tokenization / lemmatization)
import spacy

# Text splitting (chunking)
from langchain_text_splitters import RecursiveCharacterTextSplitter

# Embeddings model
from langchain_openai import OpenAIEmbeddings

# Vector database
from langchain_community.vectorstores import Chroma

# Document schema
from langchain_core.documents import Document

# LLM model
from langchain_openai import ChatOpenAI

# Tools for the agent
from langchain.tools import tool
from langchain.tools import Tool

# LangChain agent components
from langchain.agents import initialize_agent
from langchain.agents import AgentType

# Memory for conversational context
from langchain.memory import ConversationBufferMemory

# LangSmith monitoring
import os

# %%
### API KEYS Configuration

from dotenv import load_dotenv
import os

load_dotenv()
# Out:
# True

# %%
# ==========================================================
# 2. LANGSMITH CONFIGURATION
# ==========================================================
# Enables tracing and monitoring of the pipeline

import os

os.environ["LANGCHAIN_TRACING_V2"] = "true"
os.environ["LANGCHAIN_PROJECT"] = "youtube-qa-bot"

# %%
# ==========================================================
# 3. LOAD SPACY NLP MODEL
# ==========================================================
# spaCy is used for NLP preprocessing such as lemmatization

nlp = spacy.load("en_core_web_sm")

# %% [markdown]
# ## 2 Import & Datasets cleaning (YouTube Data Collection)

# %% [markdown]
# ####  List the YouTube Video IDs

# %%
# List 
video_ids = [
    "zU9eaxjEgko",
    "HGEMscZE5dY",
    "YB49-yxy5aA",
    "Hvq_qfSJvvY",
    "Z8uANLdARj8"
]

# %%
# Crate a list where to save all

all_transcripts = []

# %%
# We have 2 different possible codes to get our transcriptions

# docs = get_transcripts(video_ids)
# documents = get_youtube_transcripts(video_ids)

# %%
# ==========================================================
# DOWNLOAD YOUTUBE TRANSCRIPTS WITH VIDEO METADATA
# ==========================================================
# We save both the transcript text and the video_id
# so we can use metadata later inside the vector database.

all_transcripts = []

for video_id in video_ids:
    try:
        transcript = YouTubeTranscriptApi().fetch(video_id)
        text = " ".join([snippet.text for snippet in transcript])

        text = text.replace("\n", " ").strip()

        all_transcripts.append({
            "video_id": video_id,
            "raw_text": text
        })

        print("Transcript downloaded:", video_id)

    except Exception as e:
        print("Error with video:", video_id)
        print(e)
# Out:
# Transcript downloaded: zU9eaxjEgko
# Transcript downloaded: HGEMscZE5dY
# Transcript downloaded: YB49-yxy5aA
# Transcript downloaded: Hvq_qfSJvvY
# Transcript downloaded: Z8uANLdARj8

# %%
#Let's check if it worked(this will tell u the number of our videos)

len(all_transcripts)
# Out:
# 5

# %%
# ==========================================================
# MERGE AND CLEAN TRANSCRIPTS
# ==========================================================
# We merge all transcript texts into one large text
# for optional global preprocessing and inspection.

full_text = " ".join([item["raw_text"] for item in all_transcripts])

full_text = full_text.replace("\n", " ")
full_text = full_text.replace("  ", " ")

# %%
# ==========================================================
# NLP PREPROCESSING WITH SPACY (LEMMATIZATION)
# ==========================================================
# This function applies NLP preprocessing to text.
# It converts words into lemmas and removes stopwords
# and punctuation.

def preprocess_text(text):

    doc = nlp(text)

    lemmas = [
        token.lemma_.lower()
        for token in doc
        if not token.is_stop and not token.is_punct
    ]

    return " ".join(lemmas)


# Apply preprocessing to the merged transcript text
processed_text = preprocess_text(full_text)

print("Lemmatization completed.")
# Out:
# Lemmatization completed.

# %%
# To see the preprocessing

print(processed_text[:1000])
# Out:
# woman live inordinately hush life history hardly chance share fame man woman able difference leave mark history discuss life woman general different period time talk woman difference period help account woman treat different era account involve detail different region world role woman different story woman brim romance loss adventure triumph remorse apart occasional appearance brave woman fight social norm remember history time history remember woman serve tea life change treaty sign woman account history consider form general history give idea average person live life era woman lead regular life chance huge difference world try understand life woman specific period insight way common people lead life help able establish place woman hold life live help understanding life general common people specific period time particular region woman ancient world early year human exist solely food shelter life lot simple gradually requirement change people able create surplus food produce farming n

# %% [markdown]
# ### We now have our libraries and our merged Youtube datasets

# %% [markdown]
# ## 2 Text Processing (chunking)

# %%
documents = [
    Document(
        page_content=f"Video ID: {item['video_id']}\n\nTranscript:\n{item['raw_text']}",
        metadata={
            "source": "youtube_transcripts",
            "video_id": item["video_id"]
        }
    )
    for item in all_transcripts
]

print(f"{len(documents)} documents created.")
# Out:
# 5 documents created.

# %%
print(all_transcripts[0])
# Out:
# {'video_id': 'zU9eaxjEgko', 'raw_text': 'Woman have lived an inordinately hushed life for most of history. They hardly get the chance to share the same amount of fame as men do. There are very few women who were able to make a difference and leave a mark in history. We will discuss the lives of women in general in different periods of time and we will talk about the women who made a difference during that period. This will help us give an account of how women were treated in different eras. The accounts will also involve details from the different regions of the world where the role of women were different. The stories of women are brimming with romance, loss, adventure, triumph and remorse. However, apart from the occasional appearance of a brave woman who fought against social norms to be remembered in history, most of the times, history remembers women only for serving tea when life-changing treaties were being signed. When women are accounted for in history, they are considered as those who formed the general history giving an idea how an average person lived his or her life in an era. This is because most of the women led regular lives and did not get the chance to make huge difference in the world. Sometimes when we try to understand the lives of women in a specific period, we get an insight into the way in which the common people led their lives. So with the help of this, you will not only be able to establish the place women held and the lives they lived, it will also help you with an understanding of how life was in general for the common people in a specific period of time and in a particular region. Women of the ancient world During the early years when humans existed solely for food and shelter, life was a lot simpler. Gradually, the requirements changed and with people being able to create a surplus of the food that they produced through farming, new avenues of trade began to open. This led to the formation of societies where people relied on each other for leading their lives more comfortably. Before societies were formed, everyone was more or less equal and there was hardly any fight related to classes, status and gender. Once the societies began to take form, and governance and laws were in place, people slowly moved into a period where the standards of living did increase, but the changes were not equally distributed. This had repercussions on humanity and problems arose in the societies - problems that we may be dealing with till this day. From class separation to gender inequality, the presence of a government and society changed many things for humans. So for those who feel that equal rights for women and feminism is a concept of the twentieth century, these are phenomenon which women have been dealing with right from the ancient times. In the ancient world, the armies were made of men and most of the governing bodies employed men. So women were usually left with the job of household servants. Marriage was seen as an essential part of a society because every society depended on a high birth rate for the society to survive. Females were married soon after their puberty and they found themselves raising a family and involving themselves in family and household oriented work for most of their lives. Many women also helped in the farms because farming was largely a family business in the Ancient World. The Ancient World stressed largely on the needs and requirements of the group instead of a single person, an individual. This is what made women play their roles in the household ensuring that the household was run properly and that the family was well-fed and properly taken care of. Care of the old and disabled member of the family also fell under the care of the women. Their role began to get more etched as societies began to depend more and more on strong family foundations for a better society. While women primarily stuck to their roles in the Ancient World, there were a few who changed the course of history  ...

# %%
# =========================================================
# 3️⃣ Text Splitting (Chunking)
# Split transcripts into smaller chunks for embeddings
# =========================================================

text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=1000,
    chunk_overlap=200
)

chunks = text_splitter.split_documents(documents)

print("Number of chunks:", len(chunks))
# Out:
# Number of chunks: 193

# %%
print(chunks[0].metadata)
# Out:
# {'source': 'youtube_transcripts', 'video_id': 'zU9eaxjEgko'}

# %%
print(chunks[0].page_content[:500])
# Out:
# Video ID: zU9eaxjEgko

# %% [markdown]
# ## 4 Embeddings and Vector Database

# %%
# Initialize embedding model

embedding_model = OpenAIEmbeddings()

# %%
import shutil
import os

if os.path.exists("./chroma_db"):
    shutil.rmtree("./chroma_db")
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[27], line 5
#       2 import os
#       4 if os.path.exists("./chroma_db"):
# ----> 5     shutil.rmtree("./chroma_db")
#
# File c:\Users\quinc\anaconda3\envs\langchain311\Lib\shutil.py:787, in rmtree(path, ignore_errors, onerror, dir_fd)
#     785     # can't continue even if onerror hook returns
#     786     return
# --> 787 return _rmtree_unsafe(path, onerror)
#
# File c:\Users\quinc\anaconda3\envs\langchain311\Lib\shutil.py:629, in _rmtree_unsafe(path, onerror)
#     627         onerror(os.path.islink, fullname, sys.exc_info())
#     628         continue
# --> 629     _rmtree_unsafe(fullname, onerror)
#     630 else:
#     631     try:
#
# File c:\Users\quinc\anaconda3\envs\langchain311\Lib\shutil.py:634, in _rmtree_unsafe(path, onerror)
#     632             os.unlink(fullname)
#     633         except OSError:
# --> 634             onerror(os.unlink, fullname, sys.exc_info())
#     635 try:
#     636     os.rmdir(path)
#
# File c:\Users\quinc\anaconda3\envs\langchain311\Lib\shutil.py:632, in _rmtree_unsafe(path, onerror)
#     630 else:
#     631     try:
# --> 632         os.unlink(fullname)
#     633     except OSError:
#     634         onerror(os.unlink, fullname, sys.exc_info())
#
# PermissionError: [WinError 32] The process cannot access the file because it is being used by another process: './chroma_db\\80e1f598-7b1d-4975-bc7e-91c72e39baab\\data_level0.bin'

# %%
# Create vector database from chunks

vector_db = Chroma.from_documents(
    documents=chunks,
    embedding=embedding_model,
    collection_name="youtube_transcripts",
    persist_directory="./chroma_db"
)

# %%
#Verify Databse
vector_db._collection.count()

# %% [markdown]
# ## 5 Retrival Augmented Generation (RAG)

# %%
# Create the retriever from the vector database
# The retriever is responsible for searching the most relevant chunks
#The retriver uses search methods, often based on vector similarity or keywords, to identify the passages or documents that most closely match your query
retriever = vector_db.as_retriever(
    search_type="mmr",
    search_kwargs={
        "k": 10,
        "fetch_k": 30,
        "lambda_mult": 0.7
    }
)

# %%
# ==========================================================
# INITIALIZE THE LLM
# ==========================================================
# This model generates the final answers and tool outputs.

llm = ChatOpenAI(
    model="gpt-3.5-turbo",
    temperature=0.1
)

# %%
# ==========================================================
# TOOL 1: SEARCH TRANSCRIPTS
# ==========================================================
# This tool retrieves the most relevant transcript chunks
# from the vector database.

@tool
def search_transcripts(query: str) -> str:
    """
    Use this tool when the user asks for transcript content, details, facts,
    or wants to know what the videos say about a specific topic.
    """

    docs = retriever.get_relevant_documents(query)

    results = []
    for i, doc in enumerate(docs[:6], start=1):
        results.append(
            f"Result {i} | Video ID: {doc.metadata.get('video_id', 'unknown')}\n{doc.page_content[:1200]}"
        )

    return "\n\n".join(results)

# %%
# ==========================================================
# TOOL 2: SUMMARIZE VIDEO CONTENT
# ==========================================================
# This tool summarizes the transcript parts most relevant
# to the user's topic or question.


@tool
def summarize_video(topic: str) -> str:
    """
    Use this tool when the user asks for a summary of what the videos say
    about a topic.
    """

    docs = retriever.get_relevant_documents(topic)
    text = "\n\n".join([doc.page_content for doc in docs[:6]])

    prompt = f"""
You are summarizing content retrieved from several YouTube video transcripts.

Task:
1. Summarize only the information present in the retrieved text
2. Combine repeated ideas
3. If the retrieved text comes from multiple videos, synthesize them together
4. Do not invent missing details

Retrieved transcript content:
{text}
"""

    response = llm.invoke(prompt)
    return response.content

# %%
# ==========================================================
# TOOL 3: EXTRACT MAIN TOPICS
# ==========================================================
# This tool extracts the main topics discussed in the
# transcript sections related to the query.
@tool
def extract_topics(query: str) -> str:
    """
    Use this tool when the user asks for the main themes, general topics,
    or what the videos are mainly about.
    """

    docs = retriever.get_relevant_documents(query)
    text = "\n\n".join([doc.page_content for doc in docs[:8]])

    prompt = f"""
The following text comes from several YouTube video transcripts.

Your task:
- identify the broad topics shared across the retrieved videos
- ignore repeated details
- avoid focusing too much on one country, one anecdote, or one example
- produce 3 to 5 high-level themes

Return the answer as bullet points.

Retrieved text:
{text}
"""

    response = llm.invoke(prompt)
    return response.content

# %%
# ==========================================================
# TOOL 4: QUOTE EVIDENCE
# ==========================================================
# This tool returns supporting transcript excerpts
# for a specific question.

@tool
def quote_evidence(query: str) -> str:
    """
    Use this tool when the user asks for evidence, support, proof,
    or transcript excerpts about a specific claim or topic.
    """

    docs = retriever.get_relevant_documents(query)

    text = "\n\n".join([
        f"Video ID: {doc.metadata.get('video_id', 'unknown')}\n{doc.page_content[:1200]}"
        for doc in docs[:5]
    ])

    prompt = f"""
You are given transcript excerpts retrieved from YouTube videos.

Task:
- extract 3 short pieces of evidence relevant to the query
- keep them concise and readable
- for each piece of evidence, mention the Video ID
- only use the retrieved text
- if some retrieved text is irrelevant, ignore it

User query:
{query}

Retrieved transcript excerpts:
{text}
"""

    response = llm.invoke(prompt)
    return response.content

# %%
# ---------------------------------------------------------
# MEMORY
# ---------------------------------------------------------
# This allows the chatbot to remember previous messages
# in the conversation

memory = ConversationBufferMemory(
    memory_key="chat_history",
    return_messages=True
)

# %%
# ---------------------------------------------------------
# CREATE THE AGENT
# ---------------------------------------------------------
# The agent can decide which tool to use depending
# on the user's question

tools = [
    search_transcripts,
    summarize_video,
    extract_topics,
    quote_evidence
]

agent = initialize_agent(
    tools,
    llm,
    agent=AgentType.CONVERSATIONAL_REACT_DESCRIPTION,
    memory=memory,
    verbose=True,
    handle_parsing_errors=True,
    max_iterations=4
)

# %%
# ==========================================================
# SIMPLE TESTING AND EVALUATION
# ==========================================================
# We test the chatbot with a few sample questions.

test_questions = [
    "What are these videos mainly about?",
    "What political and religious topics appear across the videos?",
    "Give me transcript evidence about women's rights, religion, and power."
]

for q in test_questions:
    print("\nQUESTION:", q)
    answer = agent.run(q)
    print("ANSWER:", answer[:700])
    print("\n" + "="*80)

# %%
# TEST 2 USING LANGSMITH

test_questions = [
    "What are these videos mainly about?",
    "What political and religious topics appear across the videos?",
    "Give me transcript evidence about women's rights, religion, and power."
]

for q in test_questions:
    print("\nQUESTION:", q)
    print("="*80)

    answer = agent.invoke({"input": q})

    print("ANSWER:", answer["output"])
    print("\n" + "="*80)

# %%
## TEST 2 USING LANGSMITH
